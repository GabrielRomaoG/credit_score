# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from processing import Cs2DataSetPreProcessing

# %%
credit_df = pd.read_csv("credit_score_dataset_2.csv", low_memory=False)


credit_df = Cs2DataSetPreProcessing.process(credit_df)

credit_df.head()
# Out:
#    Age Occupation  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0   23  Scientist                1824.84                  3                4
# 1   23  Scientist                1824.84                  3                4
# 2   23  Scientist                1824.84                  3                4
# 3   23  Scientist                1824.84                  3                4
# 4   23  Scientist                1824.84                  3                4
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0              3            4                    3                       7
# 1              3            4                   -1                       6
# 2              3            4                    3                       7
# 3              3            4                    5                       4
# 4              3            4                    6                       6
#
# ...

# %%
credit_df.describe()
# Out:
#                  Age  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000          100000.000000      100000.000000
# mean       33.311180            4198.468542           5.368720
# std        10.764783            3187.369849           2.593498
# min        14.000000             303.650000           0.000000
# 25%        24.000000            1626.590000           3.000000
# 50%        33.000000            3096.380000           5.000000
# 75%        42.000000            5961.640000           7.000000
# max        56.000000           15204.630000          11.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# count    100000.000000   100000.00000  100000.000000        100000.000000
# mean          5.533800       14.53208       3.532880            21.068780
# std           2.067946        8.74133       2.446356            14.860104
# min           0.000000        1.00000       0.000000            -5.000000
# ...

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(credit_df, x="Monthly_Inhand_Salary", ax=axes)
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(test_df, x="Monthly_Balance", ax=axes)
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(test_df, x="Amount_invested_monthly", ax=axes)
plt.show()

# %%
# plotting the relation between the categorical features and Credit Score
categorical_columns = credit_df.select_dtypes('object').columns.to_list()
categorical_columns.remove("Credit_Score")

for column in categorical_columns:
    plt.figure(figsize=(16, 6))
    sns.countplot(x=column, hue="Credit_Score", data=credit_df)
    plt.title(f"Relation of {column} and Credit Score")
    plt.show()

# %%
numerical_columns = credit_df.select_dtypes('number').columns

for column in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=credit_df, x="Credit_Score", y=column)
    plt.title(f"Relation between {column} and Credit Score")
    plt.show()
